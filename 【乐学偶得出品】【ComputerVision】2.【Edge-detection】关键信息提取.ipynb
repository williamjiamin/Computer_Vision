# %% [markdown]
# 乐学偶得 版权所有 主讲人 ：William 由LX_LAB教研团队提供技术支持 乐学偶得版权所有  公众号：乐学Fintech  正版视频课程 网易云课堂：乐学偶得

# %% [markdown]
# ![3.Edge_Detection.png](attachment:3.Edge_Detection.png)

# %% [markdown]
# 1.What is Edge?(Object and Object)
# 2.What is Object?
# 3.How can you find the Edge?

# %% [markdown]
# ![4.EdgeModel.png](attachment:4.EdgeModel.png)

# %% [markdown]
# image 先对x和y分别做smoothing(blurred)

# %% [markdown]
# 1. Averaging

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("5.opencv.png")
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
averaging_blurred_img = cv2.blur(img,(88,88)) #tuple is the kernel size

averaging_blurred_img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(averaging_blurred_img)

# %%
plt.imshow(img)

# %%
Gaussian_Noise_img = cv2.imread("6.Gaussian_Noise.png")
plt.imshow(Gaussian_Noise_img)

# %%
Averaging_Blurred_Gaussian_Noise_img = cv2.blur(Gaussian_Noise_img,(10,10)) #tuple is the kernel size
plt.imshow(Averaging_Blurred_Gaussian_Noise_img)

# %%
Gaussian_Blurred_Gaussian_Noise_img = cv2.GaussianBlur(Gaussian_Noise_img,(15,15),0)
plt.imshow(Gaussian_Blurred_Gaussian_Noise_img)

# %% [markdown]
# ![7.Edge_Detector.png](attachment:7.Edge_Detector.png)

# %% [markdown]
# ![8.marr-hildreth.png](attachment:8.marr-hildreth.png)

# %% [markdown]
# ![10.sobel_canny.png](attachment:10.sobel_canny.png)
