# %% [markdown]
# 乐学偶得 版权所有 主讲人 ：William 由LX_LAB教研团队提供技术支持 乐学偶得版权所有  公众号：乐学Fintech  正版视频课程 网易云课堂：乐学偶得

# %%
from skimage import io,filters,color

# %%
img = io.imread("japan.jpg")
img = color.rgb2grey(img)
io.imshow(img)
io.show()

# %%
img = io.imread("5.opencv.png")
img = color.rgb2grey(img)
find_the_edge = filters.sobel(img)
io.imshow(find_the_edge)
io.show()

# %%
img = io.imread("Trevor-Noah.jpg")
img = color.rgb2grey(img)
# find_the_edge = filters.sobel(img)
io.imshow(img)
io.show()

# %%
img = io.imread("Trevor-Noah.jpg")
img = color.rgb2grey(img)
find_the_edge = filters.sobel(img)
io.imshow(find_the_edge)
io.show()
